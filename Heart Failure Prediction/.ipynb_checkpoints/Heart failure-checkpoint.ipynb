# %%
# Import pandas library and the data set
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
# Have a look at the first five rows
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
# Have a look at the data set's info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
# Check if any columns having missing data
df.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
sc = StandardScaler()

# Retrieve X_scaled and y
X = df.drop('DEATH_EVENT', axis=1).copy()
X_scaled = sc.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, index=X.index, columns=X.columns)
y = df['DEATH_EVENT'].copy()

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=1, stratify=y)

# %% [markdown]
# ## Preliminary use of Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
decisiontree = DecisionTreeClassifier(random_state=1)
decisiontree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# Plot the tree
from sklearn.tree import plot_tree
plt.figure(figsize=(15, 8))
plot_tree(decisiontree, filled=True, rounded=True, class_names=['death in period', 'not death in period'], feature_names=X.columns)
# Out:
# [Text(332.45970394736844, 413.13599999999997, 'time <= -0.81\ngini = 0.437\nsamples = 239\nvalue = [162, 77]\nclass = death in period'),
#  Text(110.13157894736842, 369.648, 'ejection_fraction <= 2.913\ngini = 0.226\nsamples = 54\nvalue = [7, 47]\nclass = not death in period'),
#  Text(88.10526315789474, 326.15999999999997, 'creatinine_phosphokinase <= -0.518\ngini = 0.201\nsamples = 53\nvalue = [6, 47]\nclass = not death in period'),
#  Text(44.05263157894737, 282.672, 'serum_sodium <= -0.482\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = not death in period'),
#  Text(22.026315789473685, 239.184, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = not death in period'),
#  Text(66.07894736842105, 239.184, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = death in period'),
#  Text(132.1578947368421, 282.672, 'diabetes <= 0.166\ngini = 0.124\nsamples = 45\nvalue = [3, 42]\nclass = not death in period'),
#  Text(110.13157894736842, 239.184, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]\nclass = not death in period'),
#  Text(154.18421052631578, 239.184, 'creatinine_phosphokinase <= -0.436\ngini = 0.236\nsamples = 22\nvalue = [3, 19]\nclass = not death in period'),
#  Text(110.13157894736842, 195.696, 'creatinine_phosphokinase <= -0.471\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = not death in period'),
#  Text(88.10526315789474, 152.20799999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = not death in period'),
#  Text(132.1578947368421, 152.20799999999997, 'serum_sodium <= 0.993\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = death in period'),
#  Text(110.13157894736842, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = death in period'),
#  Text(154.18421052631578, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(198.23684210526318, 195.696, 'creatinine_phosphokinase <= 1.212\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = not death in period'),
#  Text(176.21052631578948, 152.20799999999997, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = not death in period'),
#  Text(220.26315789473685, 152.20799999999997, 'creatinine_phosphokinase <= 2.816\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = not death in period'),
#  Text(198.23684210526318, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = death in period'),
#  Text(242.28947368421052, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = not death in period'),
#  Text(132.1578947368421, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = death in period'),
#  Text(554.7878289473684, 369.648, 'serum_creatinine <= 0.151\ngini = 0.272\nsamples = 185\nvalue = [155, 30]\nclass = death in period'),
#  Text(382.70723684210526, 326.15999999999997, 'ejection_fraction <= -0.896\ngini = 0.149\nsamples = 148\nvalue = [136, 12]\nclass = death in period'),
#  Text(242.28947368421052, 282.672, 'age <= -0.702\ngini = 0.48\nsamples = 15\nvalue = [9, 6]\nclass = death in period'),
#  Text(220.26315789473685, 239.184, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = death in period'),
#  Text(264.3157894736842, 239.184, 'serum_sodium <= -0.028\ngini = 0.496\nsamples = 11\nvalue = [5, 6]\nclass = not death in period'),
#  Text(242.28947368421052, 195.696, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = not death in period'),
#  Text(286.3421052631579, 195.696, 'ejection_fraction <= -1.319\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = death in period'),
#  Text(264.3157894736842, 152.20799999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(308.36842105263156, 152.20799999999997, 'age <= -0.407\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = death in period'),
#  Text(286.3421052631579, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(330.39473684210526, 108.72000000000003, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = death in period'),
#  Text(523.125, 282.672, 'age <= 1.53\ngini = 0.086\nsamples = 133\nvalue = [127, 6]\nclass = death in period'),
#  Text(429.5131578947369, 239.184, 'serum_creatinine <= -0.72\ngini = 0.046\nsamples = 127\nvalue = [124, 3]\nclass = death in period'),
#  Text(374.44736842105266, 195.696, 'age <= 0.14\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = death in period'),
#  Text(352.42105263157896, 152.20799999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(396.47368421052636, 152.20799999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = death in period'),
#  Text(484.57894736842104, 195.696, 'platelets <= -1.688\ngini = 0.031\nsamples = 125\nvalue = [123, 2]\nclass = death in period'),
#  Text(440.5263157894737, 152.20799999999997, 'age <= -0.365\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = death in period'),
#  Text(418.5, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(462.5526315789474, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = death in period'),
#  Text(528.6315789473684, 152.20799999999997, 'serum_creatinine <= -0.139\ngini = 0.016\nsamples = 122\nvalue = [121, 1]\nclass = death in period'),
#  Text(506.60526315789474, 108.72000000000003, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]\nclass = death in period'),
#  Text(550.6578947368421, 108.72000000000003, 'ejection_fraction <= 1.432\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = death in period'),
#  Text(528.6315789473684, 65.23199999999997, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = death in period'),
#  Text(572.6842105263158, 65.23199999999997, 'age <= 0.519\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = death in period'),
#  Text(550.6578947368421, 21.744000000000028, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = death in period'),
#  Text(594.7105263157895, 21.744000000000028, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(616.7368421052631, 239.184, 'platelets <= -0.145\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = death in period'),
#  Text(594.7105263157895, 195.696, 'diabetes <= 0.166\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = death in period'),
#  Text(572.6842105263158, 152.20799999999997, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = death in period'),
#  Text(616.7368421052631, 152.20799999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(638.7631578947369, 195.696, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = not death in period'),
#  Text(726.8684210526316, 326.15999999999997, 'creatinine_phosphokinase <= -0.526\ngini = 0.5\nsamples = 37\nvalue = [19, 18]\nclass = death in period'),
#  Text(704.8421052631579, 282.672, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = death in period'),
#  Text(748.8947368421053, 282.672, 'time <= 1.029\ngini = 0.487\nsamples = 31\nvalue = [13, 18]\nclass = not death in period'),
#  Text(704.8421052631579, 239.184, 'platelets <= -0.168\ngini = 0.386\nsamples = 23\nvalue = [6, 17]\nclass = not death in period'),
#  Text(682.8157894736843, 195.696, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = not death in period'),
#  Text(726.8684210526316, 195.696, 'high_blood_pressure <= 0.312\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = death in period'),
#  Text(704.8421052631579, 152.20799999999997, 'creatinine_phosphokinase <= 1.003\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = death in period'),
#  Text(682.8157894736843, 108.72000000000003, 'ejection_fraction <= -1.319\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = death in period'),
#  Text(660.7894736842105, 65.23199999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(704.8421052631579, 65.23199999999997, 'age <= 2.077\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = death in period'),
#  Text(682.8157894736843, 21.744000000000028, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = death in period'),
#  Text(726.8684210526316, 21.744000000000028, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(726.8684210526316, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(748.8947368421053, 152.20799999999997, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = not death in period'),
#  Text(792.9473684210527, 239.184, 'ejection_fraction <= -1.319\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = death in period'),
#  Text(770.921052631579, 195.696, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = not death in period'),
#  Text(814.9736842105264, 195.696, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = death in period')]

# %%
# Plot the confusion matrix
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(decisiontree, X_test, y_test, display_labels=['death in period', 'not death in period'])

# %% [markdown]
# We see that<br>
# - of **(30 + 11) = 42** people that die in period, **30 (73%)** were correctly classified.<br>
# - of **(7 + 12) = 19** people that did not die in period, **12 (33%)** were correctly classified.
# <br>Let's prune the tree to improve the model

# %%
# Create lists of parameter for Decision Tree Classifier
parameters = {  'criterion': ['gini'],
                'max_depth': [5],
                'splitter': ['random'],
                'min_samples_split': [6],
                'min_samples_leaf': [9],
                'max_leaf_nodes': [3],
                'max_features': ['sqrt']
}

# %% [markdown]
# ### Conduct Parameter Optmization With Pipeline

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

# Create a grid search object
grid_search = GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=parameters, scoring='accuracy', cv=5, n_jobs=-1)

# Fit the grid search
grid_search.fit(X, y)

# View The Best Parameters
print(grid_search.best_params_)
best_result = DecisionTreeClassifier(**grid_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 3, 'min_samples_leaf': 9, 'min_samples_split': 6, 'splitter': 'random'}

# %% [markdown]
# ## Find the best ccp_alpha

# %%
path = decisiontree.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas
ccp_alphas = ccp_alphas[:-1]

alpha_loop_values = []
for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=1, ccp_alpha=ccp_alpha)
    scores = cross_val_score(model, X_train, y_train, cv=5)
    alpha_loop_values.append([ccp_alpha, np.mean(scores), np.std(scores)])
    
alpha_results = pd.DataFrame(alpha_loop_values, columns=['alpha', 'mean_accuracy', 'std'])
alpha_results.plot(x='alpha', y='mean_accuracy', yerr='std', marker='o')
# Out:
# <AxesSubplot:xlabel='alpha'>

# %% [markdown]
# We can see that the best alpha is between 0.015 and 0.017

# %%
ideal_cpp_alpha = alpha_results[(alpha_results.alpha > 0.015) & (alpha_results.alpha < 0.017)].alpha
ideal_cpp_alpha = float(ideal_cpp_alpha)

# %%
ideal_cpp_alpha
# Out:
# 0.016457994286810003

# %% [markdown]
# ## Rebuild the Tree model using the best parameters

# %%
final_tree = DecisionTreeClassifier(criterion='gini', 
                                    max_depth=3, 
                                    max_features='sqrt', 
                                    max_leaf_nodes=3, 
                                    min_samples_leaf=9, 
                                    min_samples_split=6, 
                                    splitter='random', 
                                    ccp_alpha=ideal_cpp_alpha)
final_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.016457994286810003, max_depth=3,
#                        max_features='sqrt', max_leaf_nodes=3,
#                        min_samples_leaf=9, min_samples_split=6,
#                        splitter='random')

# %%
# Plot the tree
plt.figure(figsize=(15, 8))
plot_tree(final_tree, filled=True, rounded=True, class_names=['death in period', 'not death in period'], feature_names=X.columns)
# Out:
# [Text(502.20000000000005, 362.4, 'time <= -0.031\ngini = 0.437\nsamples = 239\nvalue = [162, 77]\nclass = death in period'),
#  Text(334.8, 217.44, 'time <= -0.678\ngini = 0.499\nsamples = 131\nvalue = [69, 62]\nclass = death in period'),
#  Text(167.4, 72.47999999999996, 'gini = 0.367\nsamples = 66\nvalue = [16, 50]\nclass = not death in period'),
#  Text(502.20000000000005, 72.47999999999996, 'gini = 0.301\nsamples = 65\nvalue = [53, 12]\nclass = death in period'),
#  Text(669.6, 217.44, 'gini = 0.239\nsamples = 108\nvalue = [93, 15]\nclass = death in period')]

# %%
# Plot the confusion matrix
plot_confusion_matrix(final_tree, X_test, y_test, display_labels=['death in period', 'not death in period'])

# %% [markdown]
# We see that<br>
# - of **(38 + 3) = 41** people that die in period, **38 (92%)** were correctly classified.<br>
# - of **(5 + 14) = 19** people that did not die in period, **14 (74%)** were correctly classified.
