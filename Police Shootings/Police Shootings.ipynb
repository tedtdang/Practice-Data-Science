# %%
# Import libraries and read the file

import pandas as pd
import numpy as np
import seaborn as sb
from matplotlib import pyplot as plt
# %matplotlib inline

df = pd.read_csv('Police Shootings.csv', parse_dates=['date'])

# %%
# Have a look at the table format
df.head()
# Out:
#    id                name       date   manner_of_death       armed   age  \
# 0   3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
# Drop columns name and id
df.drop(columns=['name', 'id'], inplace=True)

# %%
# Check data types
df.dtypes
# Out:
# date                       datetime64[ns]
# manner_of_death                    object
# armed                              object
# age                               float64
# gender                             object
# race                               object
# city                               object
# state                              object
# signs_of_mental_illness              bool
# threat_level                       object
# flee                               object
# body_camera                          bool
# dtype: object

# %%
# Extract columns year and month from datetime
df['month'] = df.date.dt.month
df['year'] = df.date.dt.year

# %%
df.head()
# Out:
#         date   manner_of_death       armed   age gender race           city  \
# 0 2015-01-02              shot         gun  53.0      M    A        Shelton
# 1 2015-01-02              shot         gun  47.0      M    W          Aloha
# 2 2015-01-03  shot and Tasered     unarmed  23.0      M    H        Wichita
# 3 2015-01-04              shot  toy weapon  32.0      M    W  San Francisco
# 4 2015-01-04              shot    nail gun  39.0      M    H          Evans
#
#   state  signs_of_mental_illness threat_level         flee  body_camera  \
# 0    WA                     True       attack  Not fleeing        False
# 1    OR                    False       attack  Not fleeing        False
# 2    KS                    False        other  Not fleeing        False
# 3    CA                     True       attack  Not fleeing        False
# 4    CO                    False       attack  Not fleeing        False
#
#    month  year
# 0      1  2015
# 1      1  2015
# 2      1  2015
# ...

# %%
df.groupby(by='race').mean()
# Out:
#             age  signs_of_mental_illness  body_camera     month         year
# race
# A     36.549451                 0.258065     0.172043  5.860215  2017.430108
# B     32.463893                 0.141757     0.157165  6.099384  2017.221880
# H     33.589977                 0.174058     0.117517  5.984479  2017.195122
# N     31.662338                 0.179487     0.153846  5.897436  2017.205128
# O     32.978723                 0.229167     0.125000  7.000000  2016.791667
# W     39.947196                 0.287964     0.094507  6.058562  2017.154281

# %%
plt.figure(figsize=(10, 8))
plt.pie(x=df.race)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-4bbe44344e8b> in <module>
#       1 plt.figure(figsize=(10, 8))
# ----> 2 plt.pie(x=df.race)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2816         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2817         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
# -> 2818         **({"data": data} if data is not None else {}))
#    2819
#    2820
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...
