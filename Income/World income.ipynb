# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('Income.csv')

# %%
df.sort_values(by='medianPerCapitaIncome', ascending=False)[:20].reset_index()
# Out:
#     index         country  medianHouseholdIncome  medianPerCapitaIncome  \
# 0       1          Norway                  51489                  19308
# 1       2          Sweden                  50514                  18632
# 2       0      Luxembourg                  52493                  18418
# 3       4         Denmark                  44360                  18262
# 4      26         Finland                  24615                  15725
# 5       5   United States                  43585                  15480
# 6       6          Canada                  41280                  15181
# 7       3       Australia                  46555                  15026
# 8       9     Netherlands                  38584                  14450
# 9      14         Germany                  33333                  14098
# 10     18          France                  31112                  12445
# 11     17  United Kingdom                  31617                  12399
# ...
