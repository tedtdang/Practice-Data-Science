# %%
# Import pandas library and the data set
import pandas as pd
import sidetable
from DataScience import *
df = pd.read_csv('train_ctrUa4K.csv', index_col='Loan_ID')
X_test = pd.read_csv('test_lAUu6dG.csv', index_col='Loan_ID')

# %%
# Have a look at the first five rows
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
# Have a look at the number of missing values in each column
df.stb.missing(style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_80b3661c_fc85_11ea_a438_9848271e970b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing</th>        <th class="col_heading level0 col1" >total</th>        <th class="col_heading level0 col2" >percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row0" class="row_heading level0 row0" >Credit_History</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow0_col0" class="data row0 col0" >50</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow0_col1" class="data row0 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow0_col2" class="data row0 col2" >8.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row1" class="row_heading level0 row1" >Self_Employed</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow1_col0" class="data row1 col0" >32</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow1_col1" class="data row1 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow1_col2" class="data row1 col2" >5.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row2" class="row_heading level0 row2" >LoanAmount</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow2_col0" class="data row2 col0" >22</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow2_col1" class="data row2 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow2_col2" class="data row2 col2" >3.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row3" class="row_heading level0 row3" >Dependents</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow3_col0" class="data row3 col0" >15</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow3_col1" class="data row3 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow3_col2" class="data row3 col2" >2.44%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row4" class="row_heading level0 row4" >Loan_Amount_Term</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow4_col0" class="data row4 col0" >14</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow4_col1" class="data row4 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow4_col2" class="data row4 col2" >2.28%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row5" class="row_heading level0 row5" >Gender</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow5_col0" class="data row5 col0" >13</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow5_col1" class="data row5 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow5_col2" class="data row5 col2" >2.12%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row6" class="row_heading level0 row6" >Married</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow6_col0" class="data row6 col0" >3</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow6_col1" class="data row6 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow6_col2" class="data row6 col2" >0.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row7" class="row_heading level0 row7" >Education</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow7_col0" class="data row7 col0" >0</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow7_col1" class="data row7 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row8" class="row_heading level0 row8" >ApplicantIncome</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow8_col0" class="data row8 col0" >0</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow8_col1" class="data row8 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row9" class="row_heading level0 row9" >CoapplicantIncome</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow9_col0" class="data row9 col0" >0</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow9_col1" class="data row9 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row10" class="row_heading level0 row10" >Property_Area</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow10_col0" class="data row10 col0" >0</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow10_col1" class="data row10 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_80b3661c_fc85_11ea_a438_9848271e970blevel0_row11" class="row_heading level0 row11" >Loan_Status</th>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow11_col0" class="data row11 col0" >0</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow11_col1" class="data row11 col1" >614</td>
#                         <td id="T_80b3661c_fc85_11ea_a438_9848271e970brow11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#     </tbody></table>

# %%
# Retrieve X and y
X_train = df.drop(['Loan_Status'], axis=1).copy()
y_train = df['Loan_Status'].copy()

# %%
X_train = process_sets(X_train)
X_test = process_sets(X_test)
best_grid, predictions = rfr_classifier(X_train, y_train, X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c311c50bc946> in <module>
# ----> 1 X_train = process_sets(X_train)
#       2 X_test = process_sets(X_test)
#       3 best_grid, predictions = rfr_classifier(X_train, y_train, X_test)
#
# D:\GitHub\Practice-Data-Science\Package\DataScience.py in process_sets(x)
#      20     x[num_features] = ii.fit_transform(x[num_features])
#      21     si = SimpleImputer(strategy='most_frequent')
# ---> 22     x[cat_features] = si.fit_transform(x[cat_features])
#      23
#      24     # Encode cat features
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     249                 raise new_ve from None
#     250             else:
# --> 251                 raise ve
#     252
#     253         _check_inputs_dtype(X, self.missing_values)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     242                                     accept_sparse='csc', dtype=dtype,
#     243                                     force_all_finite=force_all_finite,
# --> 244                                     copy=self.copy)
#     245         except ValueError as ve:
#     246             if "could not convert" in str(ve):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     531
#     532         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 533             dtype_orig = np.result_type(*dtypes_orig)
#     534
#     535     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required

# %%
index = X_test.index
predictions = pd.DataFrame(predictions, columns=['Loan_Status'], index=index)

# %%
# saving the DataFrame as a CSV file 
csv_data = predictions.to_csv('Predictions.csv', index = True)
